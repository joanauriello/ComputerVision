# %% [markdown]
# ###3.1. Setup & data prep (paths, unzip, split, folder structure)

# %%
# ==========================================================
# 0) Mount Google Drive (required for CSV and ZIP access)
# ==========================================================
from google.colab import drive
drive.mount('/content/drive')

print("Drive mounted.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted.

# %%
# ==========================================================
# YOLOv8 CLASSIFICATION – E-waste project
# ==========================================================
# !pip install -q ultralytics

import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix

# ----------------------------------------------------------
# 1) Paths & basic config
# ----------------------------------------------------------
WORK_DIR = '/content/drive/MyDrive/Colab Notebooks/ComputerVision'
CSV_PATH = os.path.join(WORK_DIR, 'image_labels.csv')


PROJECT_DIR = os.path.join(WORK_DIR, "experiments")
EXP_NAME_YOLO = "yolo_cls_noaug_v1"

# zip + local dir
ZIP_PATH = os.path.join(
    WORK_DIR,
    'Dataset Consolidado.zip'
)
LOCAL_RAW_DATA_DIR = "/content/Dataset_Consolidado_LOCAL"

print("WORK_DIR:", WORK_DIR)
print("CSV_PATH:", CSV_PATH)
print("ZIP_PATH:", ZIP_PATH)
print("LOCAL_RAW_DATA_DIR:", LOCAL_RAW_DATA_DIR)
# Out:
# WORK_DIR: /content/drive/MyDrive/Colab Notebooks/ComputerVision
# CSV_PATH: /content/drive/MyDrive/Colab Notebooks/ComputerVision/image_labels.csv
# ZIP_PATH: /content/drive/MyDrive/Colab Notebooks/ComputerVision/Dataset Consolidado.zip
# LOCAL_RAW_DATA_DIR: /content/Dataset_Consolidado_LOCAL

# %% [markdown]
# #### unzip and copoy in local

# %%
# ----------------------------------------------------------
# 2) Unzip dataset from Drive to local /content (fast I/O)
# ----------------------------------------------------------
if not os.path.exists(LOCAL_RAW_DATA_DIR):
    print("Unzipping dataset to local VM storage...")
    # !unzip -q "$ZIP_PATH" -d /content/

    # !mv "/content/Dataset Consolidado" "$LOCAL_RAW_DATA_DIR"
    print("Unzip complete.")
else:
    print("Local dataset already exists — fast mode enabled.")

# ----------------------------------------------------------
# 3) Load CSV and rewrite paths from Drive → local
# ----------------------------------------------------------
df_all = pd.read_csv(CSV_PATH)
print("Total images in CSV:", len(df_all))

RAW_DATA_DIR_DRIVE = os.path.join(WORK_DIR, 'Dataset Consolidado')

def convert_drive_to_local(path):
    """
    Convert a path that points to the Drive-based dataset
    into the equivalent path inside LOCAL_RAW_DATA_DIR (/content/...).
    """
    return path.replace(RAW_DATA_DIR_DRIVE, LOCAL_RAW_DATA_DIR)

df_all['image_path'] = df_all['image_path'].apply(convert_drive_to_local)

print("Example local path:", df_all.iloc[0]['image_path'])
display(df_all.head())
# Out:
# Local dataset already exists — fast mode enabled.
# Total images in CSV: 59001
# Example local path: /content/Dataset_Consolidado_LOCAL/Papel y Carton/paper_2091.jpg
#                                           image_path           label
# 0  /content/Dataset_Consolidado_LOCAL/Papel y Car...  Papel y Carton
# 1  /content/Dataset_Consolidado_LOCAL/Papel y Car...  Papel y Carton
# 2  /content/Dataset_Consolidado_LOCAL/Papel y Car...  Papel y Carton
# 3  /content/Dataset_Consolidado_LOCAL/Papel y Car...  Papel y Carton
# 4  /content/Dataset_Consolidado_LOCAL/Papel y Car...  Papel y Carton

# %% [markdown]
# ### 2. Stratigied train val test split

# %%
# ----------------------------------------------------------
# 4) Stratified train/val/test split
# ----------------------------------------------------------
SEED = 42
TRAIN_FRAC = 0.8
VAL_FRAC   = 0.1
TEST_FRAC  = 0.1

rng = np.random.default_rng(SEED)

train_idx = []
val_idx   = []
test_idx  = []

for label, group in df_all.groupby('label', sort=False):
    idx = group.index.to_numpy()
    rng.shuffle(idx)
    n_total = len(idx)

    n_train = int(n_total * TRAIN_FRAC)
    n_val   = int(n_total * VAL_FRAC)
    n_test  = n_total - n_train - n_val

    train_idx.extend(idx[:n_train])
    val_idx.extend(idx[n_train:n_train + n_val])
    test_idx.extend(idx[n_train + n_val:])

df_train = df_all.loc[train_idx].reset_index(drop=True)
df_val   = df_all.loc[val_idx].reset_index(drop=True)
df_test  = df_all.loc[test_idx].reset_index(drop=True)

print("Train images:", len(df_train))
print("Val images  :", len(df_val))
print("Test images :", len(df_test))
# Out:
# Train images: 47195
# Val images  : 5896
# Test images : 5910

# %% [markdown]
# ### 3. Build YOLO model

# %%
# ----------------------------------------------------------
# 5) Build YOLOv8 CLASSIFICATION directory structure
#    /content/yolo_ewaste_cls/{train,val,test}/{class_name}/image.jpg
# ----------------------------------------------------------
YOLO_DATA_DIR = "/content/yolo_ewaste_cls"
for split in ['train', 'val', 'test']:
    split_dir = os.path.join(YOLO_DATA_DIR, split)
    os.makedirs(split_dir, exist_ok=True)

# Get sorted class names from the labels
class_names = sorted(df_all['label'].unique())
class_to_index = {c: i for i, c in enumerate(class_names)}
index_to_class = {i: c for c, i in class_to_index.items()}

print("Number of classes:", len(class_names))
print("Sample classes:", class_names[:10])

def populate_split_folder(df_split, split_name):
    """
    For each row in df_split, create:
    YOLO_DATA_DIR/split_name/label/image_filename
    using symlinks to avoid copying the whole dataset.
    """
    split_root = os.path.join(YOLO_DATA_DIR, split_name)
    for _, row in df_split.iterrows():
        img_path = row['image_path']
        label    = str(row['label'])

        # Class folder for this split
        class_dir = os.path.join(split_root, label)
        os.makedirs(class_dir, exist_ok=True)

        # Target path (symlink)
        filename = os.path.basename(img_path)
        dst_path = os.path.join(class_dir, filename)

        # Create symlink if it doesn't exist
        if not os.path.exists(dst_path):
            try:
                os.symlink(img_path, dst_path)
            except FileExistsError:
                pass  # in case of race / reruns

print("Populating YOLO train/val/test folders with symlinks...")
populate_split_folder(df_train, 'train')
populate_split_folder(df_val,   'val')
populate_split_folder(df_test,  'test')
print("Done.")
# Out:
# Number of classes: 12
# Sample classes: ['Bio organico', 'Envase Plasticos', 'Papel y Carton', 'Reciclables Varios Cigarro', 'Reciclables Varios Electronicos', 'Reciclables Varios Madera', 'Reciclables Varios Metal', 'Reciclables Varios Otros', 'Reciclables Varios Plastico', 'Reciclables Varios Textiles']
# Populating YOLO train/val/test folders with symlinks...
# Done.

# %% [markdown]
# ### 4. Train YOLOv8 classifier

# %%
# ==========================================================
# YOLOv8 CLASSIFICATION TRAINING
# ==========================================================

from ultralytics import YOLO

# Small, fast classification model
model = YOLO('yolov8n-cls.pt')

EXP_NAME_YOLO = "yolo_cls_noaug_v1"
PROJECT_DIR = os.path.join(WORK_DIR, "experiments")

print("Starting YOLOv8 classification training...")

model.train(
    data=YOLO_DATA_DIR,   # root with train/val/test
    epochs=20,            # adjust if you want more/less
    imgsz=224,            # same as ResNet input
    batch=64,             # increase if GPU memory allows
    workers=2,            # num dataloader workers
    project=PROJECT_DIR,
    name=EXP_NAME_YOLO,
    val=True              # run validation during training
)

print("Training complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1743.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1743.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1746.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1746.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1747.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1747.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1748.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1748.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1749.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1749.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1750.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1750.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1756.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1756.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1759.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1759.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1760.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1760.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1762.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1762.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1764.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1764.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1766.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1766.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1768.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1768.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1771.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1771.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1772.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1772.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1774.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1774.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1775.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1775.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1777.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1777.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1781.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1781.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1782.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1782.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1785.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1785.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1786.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1786.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1787.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1787.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1788.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1788.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1789.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1789.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1790.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1790.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1793.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1793.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1794.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1794.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1795.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1795.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1796.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1796.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1800.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1800.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1802.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1802.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1803.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1803.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1804.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1804.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1806.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1806.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1807.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1807.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1809.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1809.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1813.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1813.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1814.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1814.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1815.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1815.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1816.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1816.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1817.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1817.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_1818.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_1818.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_827.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_827.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_828.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_828.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_829.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_829.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_830.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_830.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_835.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_835.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_837.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_837.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_838.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_838.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_839.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_839.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_840.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_840.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_841.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_841.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_842.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_842.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_844.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_844.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_845.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_845.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_846.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_846.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_847.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_847.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_848.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_848.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_849.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_849.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_850.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_850.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_851.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_851.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_852.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_852.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_853.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_853.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_854.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_854.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_855.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_855.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_856.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_856.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_860.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_860.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_861.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_861.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_862.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_862.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_863.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_863.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_864.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_864.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_866.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_866.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_867.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_867.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_869.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_869.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_870.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_870.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_873.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_873.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_874.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_874.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_877.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_877.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_878.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_878.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_880.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_880.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_882.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_882.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_884.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_884.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_886.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_886.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_887.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_887.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_889.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_889.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_890.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_890.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_892.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_892.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_893.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_893.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_894.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_894.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_895.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_895.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_898.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_898.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_900.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_900.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_901.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_901.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_902.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_902.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_904.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_904.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_905.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_905.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_906.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_906.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_907.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_907.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_910.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_910.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_911.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_911.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_912.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_912.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_915.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_915.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_916.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_916.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_918.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_918.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_919.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_919.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_920.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_920.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_921.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_921.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_923.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_923.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_926.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_926.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_929.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_929.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_930.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_930.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_935.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_935.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_936.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_936.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_939.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_939.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_940.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_940.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_941.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_941.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_942.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_942.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_943.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_943.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_944.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_944.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_946.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_946.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_947.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_947.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_948.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_948.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_950.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_950.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_951.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_951.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_953.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_953.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_954.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_954.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_956.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_956.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_960.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_960.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_965.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_965.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_967.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_967.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_969.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_969.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_970.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_970.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_971.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_971.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_972.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_972.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_973.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_973.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_974.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_974.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_976.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_976.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_977.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_977.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_980.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_980.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_982.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_982.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_983.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_983.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_984.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_984.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_988.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_988.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_990.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_990.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_991.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_991.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_992.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_992.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_993.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_993.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_996.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_996.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_997.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_997.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/img_998.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/img_998.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash1.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash1.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash10.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash10.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash100.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash100.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash101.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash101.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash103.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash103.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash104.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash104.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash105.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash105.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash109.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash109.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash11.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash11.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash110.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash110.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash111.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash111.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash113.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash113.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash116.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash116.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash117.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash117.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash118.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash118.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash119.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash119.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash12.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash12.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash120.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash120.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash121.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash121.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash122.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash122.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash123.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash123.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash124.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash124.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash125.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash125.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash127.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash127.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash128.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash128.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash129.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash129.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash130.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash130.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash131.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash131.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash132.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash132.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash133.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash133.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash134.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash134.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash135.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash135.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash136.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash136.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash138.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash138.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash139.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash139.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash141.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash141.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash142.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash142.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash143.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash143.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash144.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash144.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash145.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash145.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash147.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash147.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash148.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash148.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash149.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash149.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash15.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash15.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash150.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash150.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash151.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash151.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash152.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash152.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash153.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash153.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash154.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash154.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash155.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash155.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash156.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash156.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash158.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash158.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash159.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash159.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash16.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash16.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash160.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash160.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash161.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash161.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash162.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash162.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash167.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash167.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash169.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash169.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash17.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash17.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash171.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash171.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash172.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash172.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash173.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash173.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash174.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash174.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash175.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash175.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash178.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash178.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash179.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash179.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash18.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash18.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash181.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash181.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash182.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash182.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash183.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash183.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash184.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash184.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash185.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash185.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash186.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash186.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash187.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash187.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash188.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash188.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash189.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash189.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash19.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash19.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash190.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash190.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash191.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash191.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash192.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash192.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash195.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash195.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash197.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash197.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash198.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash198.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash199.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash199.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash2.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash2.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash20.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash20.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash201.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash201.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash202.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash202.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash203.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash203.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash204.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash204.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash205.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash205.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash206.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash206.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash207.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash207.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash208.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash208.jpg'
# train: /content/yolo_ewaste_cls/train/Todo lo demás/trash209.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/train/Todo lo demás/trash209.jpg'
# ...
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_256.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_256.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_270.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_270.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_282.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_282.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_288.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_288.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_294.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_294.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_310.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_310.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_336.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_336.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_337.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_337.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_35.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_35.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_399.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_399.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_406.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_406.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_43.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_43.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_430.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_430.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_438.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_438.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_465.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_465.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_474.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_474.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_537.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_537.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_56.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_56.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_562.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_562.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_572.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_572.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_585.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_585.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_596.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_596.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_631.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_631.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_64.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_64.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_640.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_640.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_646.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_646.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_652.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_652.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_686.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_686.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_688.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_688.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_702.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_702.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_706.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_706.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_709.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_709.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_714.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_714.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_716.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_716.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_753.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_753.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_772.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_772.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_78.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_78.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_802.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_802.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_810.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_810.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_818.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_818.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_824.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_824.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_825.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_825.jpg'
# val: /content/yolo_ewaste_cls/val/Todo lo demás/trash_832.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/yolo_ewaste_cls/val/Todo lo demás/trash_832.jpg'
# val: New cache created: /content/yolo_ewaste_cls/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000625, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 9.9MB/s 0.1s
#        1/20         0G     0.7576         60        224: 100% ━━━━━━━━━━━━ 262/262 3.8s/it 16:30
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.3s/it 55.9s
#                    all      0.949          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.1576         60        224: 100% ━━━━━━━━━━━━ 262/262 3.8s/it 16:23
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 53.2s
#                    all      0.974          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G     0.1264         60        224: 100% ━━━━━━━━━━━━ 262/262 3.8s/it 16:33
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.3s/it 56.3s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G      0.107         60        224: 100% ━━━━━━━━━━━━ 262/262 3.8s/it 16:24
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 2.8s/it 47.3s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G    0.09365         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:05
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.0s/it 50.5s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G     0.0744         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:07
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 2.9s/it 48.6s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G    0.07367         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:06
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 52.4s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G    0.06585         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:15
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 2.9s/it 48.7s
#                    all      0.986          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G    0.05536         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:17
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.3s/it 56.9s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G    0.04983         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:11
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.2s/it 54.7s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G    0.04742         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:08
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 52.5s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G    0.04224         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:05
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 53.3s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G    0.03348         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:20
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.2s/it 54.4s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G    0.03308         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:05
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 51.9s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G    0.02964         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:02
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 2.9s/it 49.8s
#                    all      0.986          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G    0.03048         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:04
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.0s/it 50.2s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G    0.02675         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:08
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 52.5s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G    0.02096         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:11
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.2s/it 53.8s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G     0.0198         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:14
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.1s/it 52.4s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G     0.0197         60        224: 100% ━━━━━━━━━━━━ 262/262 3.7s/it 16:11
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 3.2s/it 54.6s
#                    all      0.989          1
#
# 20 epochs completed in 5.698 hours.
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1/weights/last.pt, 3.0MB
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1/weights/best.pt, 3.0MB
#
# Validating /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1/weights/best.pt...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,450,252 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/yolo_ewaste_cls/train... found 47195 images in 12 classes ✅
# val: /content/yolo_ewaste_cls/val... found 5896 images in 12 classes ✅
# test: /content/yolo_ewaste_cls/test... found 5910 images in 12 classes ✅
# Downloading https://ultralytics.com/assets/Arial.Unicode.ttf to '/root/.config/Ultralytics/Arial.Unicode.ttf': 100% ━━━━━━━━━━━━ 22.2MB 83.2MB/s 0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 17/17 2.9s/it 49.2s
#                    all      0.989          1
# Speed: 0.0ms preprocess, 15.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1
# Training complete.

# %%
# !find /content/yolo_ewaste_cls/train -type f | wc -l
# !find /content/yolo_ewaste_cls/val -type f | wc -l
# Out:
# 0
# 0

# %%
print("CSV train size:", len(df_train))
print("CSV val size:", len(df_val))
# Out:
# CSV train size: 47195
# CSV val size: 5896

# %%
import os
exists = df_test['image_path'].apply(os.path.exists)
print("Total test rows in CSV:", len(df_test))
print("Files that actually exist:", exists.sum())
print("Missing files:", (~exists).sum())
# Out:
# Total test rows in CSV: 5910
# Files that actually exist: 2097
# Missing files: 3813

# %% [markdown]
# ### 5. Evaluate YOLO on the test set (classification report + confusion matrix)

# %%
DRIVE_BASE = "/content/drive/MyDrive/Colab Notebooks/ComputerVision/Dataset Consolidado"

df_all["image_path"] = df_all["image_path"].apply(
    lambda p: str(p).replace("/content/Dataset_Consolidado_LOCAL", DRIVE_BASE)
)

# %%
sum(df_all['image_path'].apply(os.path.exists))
# Out:
# 59001

# %%
# ==========================================================
# FULL EVALUATION PIPELINE (NO TRAINING)
# Fixes paths, rebuilds split, evaluates trained model
# ==========================================================

# 1) Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2) Install ultralytics
# !pip install -q ultralytics

# 3) Imports
import os
import numpy as np
import pandas as pd
from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import torch

# ----------------------------------------------------------
# 4) DEFINE PATHS
# ----------------------------------------------------------
WORK_DIR = "/content/drive/MyDrive/Colab Notebooks/ComputerVision"
CSV_PATH = os.path.join(WORK_DIR, "image_labels.csv")
PROJECT_DIR = os.path.join(WORK_DIR, "experiments")
EXP_NAME_YOLO = "yolo_cls_noaug_v1"

DATASET_DRIVE_DIR = os.path.join(WORK_DIR, "Dataset Consolidado")

print("CSV:", CSV_PATH)
print("Dataset folder:", DATASET_DRIVE_DIR)

# ----------------------------------------------------------
# 5) LOAD CSV + FIX PATHS
# ----------------------------------------------------------
df_all = pd.read_csv(CSV_PATH)

def fix_path(p):
    """Convert temporary Colab paths → Drive paths."""
    p = str(p)
    return p.replace("/content/Dataset_Consolidado_LOCAL", DATASET_DRIVE_DIR)

df_all["image_path"] = df_all["image_path"].apply(fix_path)

# Sanity check
print("\nSample fixed paths:")
display(df_all.head())

# Count how many files actually exist
exists = df_all["image_path"].apply(os.path.exists)
print("\nTotal images in CSV:", len(df_all))
print("Images actually found on Drive:", exists.sum())

# ----------------------------------------------------------
# 6) REBUILD TRAIN/VAL/TEST SPLIT (must match training)
# ----------------------------------------------------------
SEED = 42
TRAIN_FRAC = 0.8
VAL_FRAC   = 0.1
TEST_FRAC  = 0.1

rng = np.random.default_rng(SEED)
train_idx, val_idx, test_idx = [], [], []

for label, group in df_all.groupby("label", sort=False):
    idx = group.index.to_numpy()
    rng.shuffle(idx)

    n = len(idx)
    n_train = int(n * TRAIN_FRAC)
    n_val   = int(n * VAL_FRAC)
    n_test  = n - n_train - n_val

    train_idx.extend(idx[:n_train])
    val_idx.extend(idx[n_train:n_train+n_val])
    test_idx.extend(idx[n_train+n_val:])

df_test = df_all.loc[test_idx].reset_index(drop=True)

print("\nTest set size (CSV):", len(df_test))

# ----------------------------------------------------------
# 7) FILTER OUT MISSING TEST IMAGES
# ----------------------------------------------------------
valid_paths = []
valid_labels = []

class_names = sorted(df_all["label"].unique())
class_to_index = {c:i for i,c in enumerate(class_names)}

for path, label in zip(df_test["image_path"], df_test["label"]):
    if os.path.exists(path):
        valid_paths.append(path)
        valid_labels.append(class_to_index[label])
    else:
        print("[MISSING]", path)

valid_labels = np.array(valid_labels)

print("\nUsable test images:", len(valid_paths))

if len(valid_paths) == 0:
    raise RuntimeError("No test images found. Path conversion might be wrong.")

# ----------------------------------------------------------
# 8) LOAD TRAINED MODEL
# ----------------------------------------------------------
BEST_WEIGHTS = os.path.join(
    PROJECT_DIR, EXP_NAME_YOLO, "weights", "best.pt"
)

print("\nLoading model:", BEST_WEIGHTS)
model = YOLO(BEST_WEIGHTS)

# ----------------------------------------------------------
# 9) RUN EVALUATION IN SMALL BATCHES (MEMORY SAFE)
# ----------------------------------------------------------
print("\nRunning evaluation...")

all_probs = []
CHUNK = 256      # number of paths per predict() call
PRED_BATCH = 64  # YOLO internal batch size

for start in range(0, len(valid_paths), CHUNK):
    end = min(start + CHUNK, len(valid_paths))
    sub_paths = valid_paths[start:end]

    print(f"  Processing {start} → {end-1}")

    results = model.predict(
        source=sub_paths,
        imgsz=224,
        batch=PRED_BATCH,
        verbose=False
    )

    for r in results:
        all_probs.append(r.probs.data.cpu().numpy())

    del results
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

pred_probs = np.stack(all_probs)
pred_labels = np.argmax(pred_probs, axis=1)

# ----------------------------------------------------------
# 10) REPORT
# ----------------------------------------------------------
print("\n=== YOLOv8 CLASSIFICATION REPORT (TEST) ===\n")
print(classification_report(valid_labels, pred_labels, target_names=class_names))

cm = confusion_matrix(valid_labels, pred_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("YOLOv8 Confusion Matrix (TEST)")
plt.tight_layout()
plt.show()

acc = (valid_labels == pred_labels).mean()
print(f"\nOverall TEST accuracy: {acc:.4f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV: /content/drive/MyDrive/Colab Notebooks/ComputerVision/image_labels.csv
# Dataset folder: /content/drive/MyDrive/Colab Notebooks/ComputerVision/Dataset Consolidado
#
# Sample fixed paths:
#                                           image_path           label
# 0  /content/drive/MyDrive/Colab Notebooks/Compute...  Papel y Carton
# 1  /content/drive/MyDrive/Colab Notebooks/Compute...  Papel y Carton
# 2  /content/drive/MyDrive/Colab Notebooks/Compute...  Papel y Carton
# 3  /content/drive/MyDrive/Colab Notebooks/Compute...  Papel y Carton
# 4  /content/drive/MyDrive/Colab Notebooks/Compute...  Papel y Carton
# Total images in CSV: 59001
# Images actually found on Drive: 59001
#
# Test set size (CSV): 5910
#
# Usable test images: 5910
#
# Loading model: /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1/weights/best.pt
#
# Running evaluation...
#   Processing 0 → 255
#   Processing 256 → 511
#   Processing 512 → 767
#   Processing 768 → 1023
#   Processing 1024 → 1279
#   Processing 1280 → 1535
#   Processing 1536 → 1791
#   Processing 1792 → 2047
#   Processing 2048 → 2303
#   Processing 2304 → 2559
#   Processing 2560 → 2815
#   Processing 2816 → 3071
#   Processing 3072 → 3327
#   Processing 3328 → 3583
#   Processing 3584 → 3839
#   Processing 3840 → 4095
#   Processing 4096 → 4351
#   Processing 4352 → 4607
#   Processing 4608 → 4863
#   Processing 4864 → 5119
#   Processing 5120 → 5375
#   Processing 5376 → 5631
#   Processing 5632 → 5887
#   Processing 5888 → 5909
#
# === YOLOv8 CLASSIFICATION REPORT (TEST) ===
#
#                                  precision    recall  f1-score   support
#
#                    Bio organico       0.50      1.00      0.66       769
#                Envase Plasticos       0.20      0.97      0.33       399
#                  Papel y Carton       0.38      0.99      0.55       929
#      Reciclables Varios Cigarro       0.00      0.00      0.00        17
# Reciclables Varios Electronicos       0.00      0.00      0.00       333
#       Reciclables Varios Madera       0.00      0.00      0.00        84
#        Reciclables Varios Metal       0.00      0.00      0.00       309
#        Reciclables Varios Otros       0.00      0.00      0.00        91
#     Reciclables Varios Plastico       0.00      0.00      0.00       312
#     Reciclables Varios Textiles       0.00      0.00      0.00      1724
#       Reciclables Varios Vidrio       0.00      0.00      0.00       706
#                  Todo lo demás       0.00      0.00      0.00       237
#
#                        accuracy                           0.35      5910
#                       macro avg       0.09      0.25      0.13      5910
#                    weighted avg       0.14      0.35      0.19      5910
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Overall TEST accuracy: 0.3506

# %% [markdown]
# ###Eval

# %% [markdown]
# Misclassification confidence histogram (YOLO)

# %%
# ==========================================================
# YOLO – Misclassification Confidence Histogram (UPDATED)
# ==========================================================
import numpy as np
import matplotlib.pyplot as plt

# true labels    -> valid_labels
# predicted      -> pred_labels
# probabilities  -> pred_probs

incorrect_idx = np.where(pred_labels != valid_labels)[0]

if len(incorrect_idx) == 0:
    print("No misclassifications found!")
else:
    # confidence of the predicted (wrong) class
    incorrect_conf = pred_probs[incorrect_idx, pred_labels[incorrect_idx]]

    plt.figure(figsize=(8, 5))
    plt.hist(incorrect_conf, bins=20, edgecolor='black')
    plt.title(f"Confidence for Incorrect Predictions - {EXP_NAME_YOLO}")
    plt.xlabel("Predicted Probability")
    plt.ylabel("Count of Misclassified Samples")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(f"Number of misclassified samples: {len(incorrect_idx)}")
# Out:
# Number of misclassified samples: 3838

# %% [markdown]
# Correct vs Incorrect confidence comparison

# %%
# ==========================================================
# YOLO – Correct vs Incorrect Prediction Confidence (UPDATED)
# ==========================================================

# correct and incorrect indices
correct_idx   = np.where(pred_labels == valid_labels)[0]
incorrect_idx = np.where(pred_labels != valid_labels)[0]

# confidence for correct predictions
correct_conf = pred_probs[correct_idx, pred_labels[correct_idx]]

# confidence for incorrect predictions
incorrect_conf = pred_probs[incorrect_idx, pred_labels[incorrect_idx]]

# Plot
plt.figure(figsize=(10, 5))
plt.hist(correct_conf,   bins=20, alpha=0.6, label="Correct",   edgecolor='black')
plt.hist(incorrect_conf, bins=20, alpha=0.6, label="Incorrect", edgecolor='black')
plt.title(f"Correct vs Incorrect Prediction Confidence - {EXP_NAME_YOLO}")
plt.xlabel("Predicted Probability")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"Correct predictions: {len(correct_idx)}")
print(f"Incorrect predictions: {len(incorrect_idx)}")
# Out:
# Correct predictions: 2072
# Incorrect predictions: 3838

# %% [markdown]
# ROC curves for all classes (YOLO)

# %%
# ==========================================================
# YOLO – ROC Curves (one-vs-rest)  (UPDATED)
# ==========================================================
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

# Number of classes
num_classes = len(class_names)

# Binarize true labels: shape (N_test, num_classes)
y_true_bin = label_binarize(valid_labels, classes=range(num_classes))

plt.figure(figsize=(10, 8))

for i in range(num_classes):
    # Calculate ROC for class i vs rest
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc = auc(fpr, tpr)

    class_name = class_names[i]
    plt.plot(fpr, tpr, lw=2, label=f"{class_name} (AUC = {roc_auc:.2f})")

# Baseline chance curve
plt.plot([0, 1], [0, 1], "k--", lw=1)

plt.title(f"ROC Curves (TEST) - {EXP_NAME_YOLO}")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right", fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# YOLO training curves over epochs

# %%
# ==========================================================
# YOLOv8 – Training Curves from results.csv (UPDATED)
# ==========================================================
import os
import pandas as pd
import matplotlib.pyplot as plt

# PROJECT_DIR and EXP_NAME_YOLO must already be defined
results_path = os.path.join(PROJECT_DIR, EXP_NAME_YOLO, "results.csv")
print("Reading training log from:", results_path)

df_hist = pd.read_csv(results_path)
print("\nHead of results.csv:")
print(df_hist.head())

print("\nAvailable columns in results.csv:")
print(df_hist.columns.tolist())

# ---- Accuracy curve (Top-1) ----
if "metrics/accuracy_top1" in df_hist.columns:
    acc_col = "metrics/accuracy_top1"
elif "metrics/accuracy" in df_hist.columns:
    acc_col = "metrics/accuracy"
else:
    raise KeyError("Could not find a Top-1 accuracy column in results.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_hist["epoch"], df_hist[acc_col], label="Val Top-1 Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title(f"YOLOv8 Training – Validation Accuracy over Epochs - {EXP_NAME_YOLO}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Loss curves (train & val) ----
train_loss_col = "train/loss"
val_loss_col   = "val/loss"

if train_loss_col not in df_hist.columns or val_loss_col not in df_hist.columns:
    raise KeyError("train/loss or val/loss not found in results.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_hist["epoch"], df_hist[train_loss_col], label="Train loss")
plt.plot(df_hist["epoch"], df_hist[val_loss_col],   label="Val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"YOLOv8 Training – Loss over Epochs - {EXP_NAME_YOLO}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Reading training log from: /content/drive/MyDrive/Colab Notebooks/ComputerVision/experiments/yolo_cls_noaug_v1/results.csv
#
# Head of results.csv:
#    epoch     time  train/loss  metrics/accuracy_top1  metrics/accuracy_top5  \
# 0      1  1045.67     0.75757                0.94893                      1
# 1      2  2082.80     0.15764                0.97375                      1
# 2      3  3132.61     0.12636                0.97041                      1
# 3      4  4164.46     0.10696                0.97613                      1
# 4      5  5179.68     0.09365                0.98377                      1
#
#    val/loss    lr/pg0    lr/pg1    lr/pg2
# 0   0.13934  0.000208  0.000208  0.000208
# 1   0.08071  0.000395  0.000395  0.000395
# 2   0.08792  0.000562  0.000562  0.000562
# 3   0.07435  0.000532  0.000532  0.000532
# 4   0.04991  0.000501  0.000501  0.000501
#
# Available columns in results.csv:
# ['epoch', 'time', 'train/loss', 'metrics/accuracy_top1', 'metrics/accuracy_top5', 'val/loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']

# %% [markdown]
# Grids of correctly vs incorrectly classified images

# %%
# ==========================================================
# YOLOv8 – Visualize Correct vs Incorrect Test Predictions (UPDATED)
# ==========================================================
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# index_to_class from class_names used in evaluation
index_to_class = {i: c for i, c in enumerate(class_names)}

# 1) Indices of correct / incorrect predictions
correct_idx   = np.where(pred_labels == valid_labels)[0]
incorrect_idx = np.where(pred_labels != valid_labels)[0]

print(f"Correctly classified test images   : {len(correct_idx)}")
print(f"Incorrectly classified test images : {len(incorrect_idx)}")

# Use only the usable test paths (aligned with valid_labels / pred_labels / pred_probs)
filepaths_test = np.array(valid_paths)

def show_examples(indices, n=9, title="Examples", index_to_class=None):
    """
    indices: array of indices in the *usable* test set
    n: number of images to display
    index_to_class: dict int -> class name
    """
    if len(indices) == 0:
        print(f"No examples to show for: {title}")
        return

    n = min(n, len(indices))
    chosen = np.random.choice(indices, size=n, replace=False)

    cols = 3
    rows = int(np.ceil(n / cols))

    plt.figure(figsize=(cols * 4, rows * 4))
    plt.suptitle(title, fontsize=16)

    for i, idx in enumerate(chosen, start=1):
        img_path = filepaths_test[idx]
        true_label_idx = valid_labels[idx]
        pred_label_idx = pred_labels[idx]
        probs = pred_probs[idx]
        pred_conf = probs[pred_label_idx]

        if index_to_class:
            true_label = index_to_class.get(true_label_idx, str(true_label_idx))
            pred_label = index_to_class.get(pred_label_idx, str(pred_label_idx))
        else:
            true_label = str(true_label_idx)
            pred_label = str(pred_label_idx)

        # Load image
        img = Image.open(img_path).convert("RGB")

        plt.subplot(rows, cols, i)
        plt.imshow(img)
        plt.axis("off")
        plt.title(
            f"True: {true_label}\nPred: {pred_label} ({pred_conf:.2f})",
            fontsize=10
        )

    plt.tight_layout(rect=[0, 0, 1, 0.93])
    plt.show()

# 2) Show some CORRECT predictions
show_examples(
    correct_idx,
    n=9,
    title=f"Correctly classified test images - {EXP_NAME_YOLO}",
    index_to_class=index_to_class
)

# 3) Show some INCORRECT predictions
show_examples(
    incorrect_idx,
    n=9,
    title=f"Incorrectly classified test images - {EXP_NAME_YOLO}",
    index_to_class=index_to_class
)
# Out:
# Correctly classified test images   : 2072
# Incorrectly classified test images : 3838
